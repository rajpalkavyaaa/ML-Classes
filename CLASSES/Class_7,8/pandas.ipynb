# %%
! pip3 insttall pandas
# Out:
# ERROR: unknown command "insttall" - maybe you meant "install"

# %%
! pip3 install pandas
# Out:
# ...
#      |████████████████████████████████| 10.8 MB 201 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 508 kB 84 kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 348 kB 184 kB/s eta 0:00:01
# ...
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/kavyarajpal/Downloads/ML/.venv/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd 
import numpy as np

# %%
# Pandas puts names on the rows and columns
restaurant_data = {
    'Table_No': [12,13,14],
    'Bill_Amount':[1250,898,2400],
    'Waiter_Name':['Amit','Priya','Rahul']
}
df = pd.DataFrame(restaurant_data)
print(df)
# Out:
#    Table_No  Bill_Amount Waiter_Name
# 0        12         1250        Amit
# 1        13          898       Priya
# 2        14         2400       Rahul

# %%
total_bill=[4700,8000,1200,500]
s = pd.Series(total_bill,index=['mon','tues','fri','sun'])
print(s)
print(type(s))
# Out:
# mon     4700
# tues    8000
# fri     1200
# sun      500
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
night_order =['Pizza','Burger','Pasta','Fries']
se = pd.Series(night_order,index=['45','30','15','60'])
print(s)
# Out:
# mon     4700
# tues    8000
# fri     1200
# sun      500
# dtype: int64

# %%
df = pd.read_csv("tip.csv")
